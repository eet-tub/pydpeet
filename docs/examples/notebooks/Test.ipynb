# %%
import pydpeet.convert
import pydpeet.convert.configs
import pydpeet.convert.configs.config
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Anton\anaconda3\envs\PyDPEET_dev\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import pydpeet.convert
#
#   File ~\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\__init__.py:1
#     import .convert import convert
#            ^
# SyntaxError: invalid syntax

# %%
pydpeet.convert.convert.convert(eet.convert.configs.config.Config.Neware, input_file="data/Neware_sample.csv", output_file="output/converted_Neware_sample.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pydpeet.convert.convert.convert(eet.convert.configs.config.Config.Neware, input_file="data/Neware_sample.csv", output_file="output/converted_Neware_sample.csv")
#
# File ~\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\utils\timing.py:29, in measure_time.<locals>.wrapper(*args, **kwargs)
#      18 """
#      19 A wrapped function that, when called, executes the original function and prints the time taken to execute it.
#      20
#    (...)     26     Any: The result of the original function.
#      27 """
#      28 start_time = time.perf_counter()
# ---> 29 result = func(*args, **kwargs)
#      30 end_time = time.perf_counter()
#      31 print(f"{func.__name__} executed in {end_time - start_time:.6f} seconds")
#
# ...
