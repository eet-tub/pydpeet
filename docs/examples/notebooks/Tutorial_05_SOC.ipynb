# %%
import pydpeet as eet
import matplotlib.pyplot as plt

# %%
Data = eet.convert.convert_file(config = 'Neware', input_path = r"..\..\res\raw\Cal_Ageing_Checkup1.xlsx")
Data.head()
# Out:
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup1.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# Handling sheets cycle, step and test...
# merging cycle and step...
# merging record and auxvol...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# handling final merge...
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# ...

# %%
Data_segmented = eet.process.sequence.step_analyzer_primitives(Data)
Data_segmented.head()
# Out:
# Input Warning: Using EXAMPLE_STEP_ANALYZER_PRIMITIVES_CONFIG as fallback configuration. Manual Parameters will be kept.
# Input Warning: Dropping NaN values in 'Testtime[s]', dropping duplicates and sorting 'Testtime[s]' column.
#     0.3079s precompiling step_analyzer_primitives and df_primitives_correction
# detecting segments in dataframe of size 163770...
#     0.0009s calculating Power[W]
#     0.0010s separating Voltage[V] into segments using incremental linear fit
#     0.0008s separating Current[A] into segments using incremental linear fit
#     0.0009s separating Power[W] into segments using incremental linear fit
#     0.0012s adding Length_Segment_Voltage[V] to calculate the dominating segments
#     0.0014s adding Length_Segment_Current[A] to calculate the dominating segments
#     0.0013s adding Length_Segment_Power[W] to calculate the dominating segments
#     0.0037s suppressing smaller segments
#     0.0175s attempting to merge neighboring segments
# ...

# %%
Battery_Config = eet.process.analyze.am23nmc
method = eet.process.analyze.SocMethod.WITHOUT_RESET

# todo: is it possible to probide acces to the Batemo/About-Energy database and fetch battery configs directly from there?
# todo: or we download it and provide the databse directly?

Result = eet.process.analyze.add_soc(
    df=Data,
    df_primitives=Data_segmented,
    standard_method=method,
    config=Battery_Config
)
Result.head()
# Out:
# analyzing segments...
#     0.0030s filtering by ID
#     0.0037s tag simple segments
#     0.0058s tag sequences
#     0.0606s assign longest sequence
#     0.0005s separate sequences and df_with_segments
#  Input Warning: Using default standard columns: ['Testtime[s]', 'Voltage[V]', 'Current[A]', 'Power[W]']
#  Input Warning: Using default standard columns: ['Testtime[s]', 'Voltage[V]', 'Current[A]', 'Power[W]']
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\process\analyze\calculations\soc_methods.py:191: UserWarning: Column 'Capacity[Ah]' missing, adding with function add_capacity.
#   warnings.warn("Column 'Capacity[Ah]' missing, adding with function add_capacity.")
#                                               Metadata  StepID  Voltage[V]  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...       0      3.5269
# 1.0                                               None       0      3.5287
# ...
