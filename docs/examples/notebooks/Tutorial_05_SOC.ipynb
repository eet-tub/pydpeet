# %%
import pydpeet as eet
import matplotlib.pyplot as plt

# %%
Data = eet.convert_file(config = 'Neware', input_path = r"..\..\res\raw\Cal_Ageing_Checkup1.xlsx")
# Out:
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup1.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# Handling sheets cycle, step and test...
# merging cycle and step...
# handling test sheet...
# merging cycle_step_test and test...
# merging record and auxvol...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# handling final merge...
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 8.378827 seconds

# %%
Battery_Config = eet.process.analyze.am23nmc



# todo: is it possible to probide acces to the Batemo/About-Energy database and fetch battery configs directly from there?
# todo: or we download it and provide the databse directly?

eet.process.analyze.add_soc(Data, Data, standard_method=True, config=Battery_Config) # todo: fix
# Out:
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\process\analyze\calculations\soc_methods.py:190: UserWarning: Column 'Capacity[Ah]' missing, adding with function add_capacity.
#   warnings.warn("Column 'Capacity[Ah]' missing, adding with function add_capacity.")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       1 Battery_Config = eet.process.analyze.am23nmc
#       5 # todo: is it possible to probide acces to the Batemo database and fetch battery configs directly from there?
#       6 # todo: or we download it and provide the databse directly?
# ----> 8 eet.process.analyze.add_soc(Data, Data, standard_method=True, config=Battery_Config) # todo: fix
#
# File ~\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\process\analyze\calculations\soc_methods.py:195, in add_soc(df, df_primitives, neware_bool, standard_method, methods, config, lower_soc_for_voltage, upper_soc_for_voltage, lower_voltage_for_soc, upper_voltage_for_soc, verbose, restart_for_testindex)
#     193             logging.info("df_primitives is None, please provide a valid df_primitives for add_capacity function")
#     194         else:
# --> 195             df = add_capacity(df, neware_bool, df_primitives, config=config, verbose=verbose)
#     196             st.log("added Capacity[Ah] column")
#     198 # Copy df so it can be safely modified
#
# File ~\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\process\analyze\calculations\capacity.py:60, in add_capacity(df, df_primitives, neware_bool, config, verbose)
#      58 # Step 2: Segments and sequences
#      59 with StepTimer(verbose) as st:
# ---> 60     df_segments_and_sequences = step_analyzer_seqments_and_sequences(df_primitives, SEGMENT_SEQUENCE_CONFIG=SEGMENT_SEQUENCE_CONFIG)
#      61     st.log("computed segments and sequences")
#      63 if neware_bool:
#      64     # Step 3: Filter discharge blocks
#
# File ~\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\process\sequence\step_analyzer.py:336, in step_analyzer_seqments_and_sequences(df_primitives, SEGMENT_SEQUENCE_CONFIG, SHOW_RUNTIME)
#     333     raise ValueError("SEGMENT_SEQUENCE_CONFIG is None or not a dict")
#     335 if df_primitives is None or not isinstance(df_primitives, pd.DataFrame):
# --> 336     raise ValueError("df_primitives is None or not a DataFrame")
#     338 standard_columns = ['Testtime[s]', 'Voltage[V]', 'Current[A]', 'Power[W]', "ID", "Variable", "Duration", "Length", "Min", "Max", "Avg", "Type", "Direction", "Slope"]
#     339 if not set(standard_columns).issubset(set(df_primitives.columns)):
#
# ValueError: df_primitives is None or not a DataFrame
