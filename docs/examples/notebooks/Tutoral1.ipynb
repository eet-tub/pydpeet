# %%
import pydpeet as eet

# %%
eet.convert(eet.convert.Config.Neware)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 eet.convert(eet.convert.Config.Neware)
#
# AttributeError: 'function' object has no attribute 'Config'
