# %%
import pydpeet as eet
import matplotlib.pyplot as plt

# %% [markdown]
# Optionally set a logging_style to show additional Infos (Useful when running heavy workloads to see the progress)

# %%
eet.utils.set_logging_style(level="INFO", formatting_string="%(levelname)s | %(pathname)s:%(lineno)d | %(message)s")

# %% [markdown]
# Convert/Import Single files into a unified Dataframe for easy and fast Processing and Analysis

# %%
Data = eet.convert.convert_file(config = 'Neware', input_path = r"..\..\res\raw\Cal_Ageing_Checkup1.xlsx")
Data.head()
# Out:
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:83 | converting file to pandas DataFrame...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:65 | Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup1.xlsx...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:271 | hadling record auxvol auxtemp sheets...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:208 | Handling sheets cycle, step and test...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:311 | checking if headers need to be reindexed...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:209 | merging cycle and step...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:313 | reindexing headers...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:233 | handling test sheet...
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:282 | merging record and auxvol...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:214 | merging cycle_step_test and test...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:311 | checking if headers need to be reindexed...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:313 | reindexing headers...
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:288 | merging record_auxvol and auxtemp...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:338 | handling final merge...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:123 | mapping columns...
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:161 | dropping additional data...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:188 | adding metadata to Dataframe...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:223 | Getting columns in correct order...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:231 | Checking for duplicate extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:236 | Selecting and ordering standard columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:239 | Selecting extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:242 | Combining standard and extra columns...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:246 | Reordered DataFrame columns!
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:317 | Starting to fix data format...
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:339 | Using formatter for config: Config.Neware
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\convert.py:345 | Data format fixed.
# INFO | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\utils\timing.py:32 | convert_file executed in 3.470120 seconds
#                                               Metadata  StepID  Voltage[V]  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...       0      3.5269
# 1.0                                               None       0      3.5287
# 2.0                                               None       0      3.5298
# 3.0                                               None       0      3.5307
# 4.0                                               None       0      3.5315
#
#      Current[A]  Temperature[°C]  Testtime[s]  \
# 0.0      1.4378             27.8          0.0
# 1.0      1.4398             27.8          1.0
# 2.0      1.4400             27.8          2.0
# 3.0      1.4400             27.8          3.0
# 4.0      1.4401             27.8          4.0
#
#     Absolute Time[yyyy-mm-dd hh:mm:ss] EISFreq[Hz] Zre[Ohm] Zim[Ohm]  \
# 0.0                2024-02-01 10:09:04        None     None     None
# 1.0                2024-02-01 10:09:05        None     None     None
# 2.0                2024-02-01 10:09:06        None     None     None
# 3.0                2024-02-01 10:09:07        None     None     None
# 4.0                2024-02-01 10:09:08        None     None     None
#
#     DC_Current[A]
# 0.0          None
# 1.0          None
# 2.0          None
# 3.0          None
# 4.0          None

# %% [markdown]
# Overwrite the previous logging_style to only show Warnings and Errors following the default format

# %%
eet.utils.set_logging_style()

# %% [markdown]
# Convert/Import files from one directory into a list of Dataframe or when you give and export path it gets directly exortet as parquet file.

# %%
Datas = eet.convert.convert_files_in_directory(config = 'Neware', input_path = r'..\..\res\raw')
# eet.convert_files_in_directory(config = 'Neware', input_path = r'..\..\res\raw', output_path = r'..\..\res\processed\converted', output_format = 'parquet')
# Out:
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
# WARNING | D:\Coding\PyDPEET_BA\pythonProject\pydpeet\src\pydpeet\convert\map.py:47 | Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.

# %% [markdown]
# After youre work is done you can export youre unifed and/or analyzed file.

# %%
eet.convert.export() # todo: export files and list of files
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 eet.convert.export() # todo: export files and list of files
#
# TypeError: export() missing 3 required positional arguments: 'data_frame', 'output_path', and 'output_file_name'
