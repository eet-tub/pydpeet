# %%
import pydpeet as eet
import matplotlib.pyplot as plt

# %% [markdown]
# Convert/Import Single files into a unified Dataframe for easy and fast Processing and Analyzis

# %%
Data = eet.convert_file(config = 'Neware', input_path = r"..\..\res\raw\Cal_Ageing_Checkup1.xlsx")
Data.head()
# Out:
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup1.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# Handling sheets cycle, step and test...
# merging cycle and step...
# merging record and auxvol...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# handling final merge...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 7.561766 seconds
#                                               Metadata  StepID  Voltage[V]  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...       0      3.5269
# 1.0                                               None       0      3.5287
# 2.0                                               None       0      3.5298
# 3.0                                               None       0      3.5307
# 4.0                                               None       0      3.5315
#
#      Current[A]  Temperature[°C]  Testtime[s]  \
# 0.0      1.4378             27.8          0.0
# 1.0      1.4398             27.8          1.0
# 2.0      1.4400             27.8          2.0
# 3.0      1.4400             27.8          3.0
# 4.0      1.4401             27.8          4.0
#
#     Absolute Time[yyyy-mm-dd hh:mm:ss] EISFreq[Hz] Zre[Ohm] Zim[Ohm]  \
# 0.0                2024-02-01 10:09:04        None     None     None
# 1.0                2024-02-01 10:09:05        None     None     None
# 2.0                2024-02-01 10:09:06        None     None     None
# 3.0                2024-02-01 10:09:07        None     None     None
# 4.0                2024-02-01 10:09:08        None     None     None
#
#     DC_Current[A]
# 0.0          None
# 1.0          None
# 2.0          None
# 3.0          None
# 4.0          None

# %% [markdown]
# Convert/Import files from one directory into a list of Dataframe or when you give and export path it gets directly exortet as parquet file.

# %%
Datas = eet.convert_files_in_directory(config = 'Neware', input_path = r'..\..\res\raw')
# eet.convert_files_in_directory(config = 'Neware', input_path = r'..\..\res\raw', output_path = r'..\..\res\processed\converted', output_format = 'parquet')
# Out:
# Processing file: Cal_Ageing_Checkup1.xlsx
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup1.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record and auxvol...
# Handling sheets cycle, step and test...
# merging cycle and step...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# handling final merge...
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 11.528903 seconds
# Successfully processed: Cal_Ageing_Checkup1_Neware_2026-01-13_22-41-44
# Processing file: Cal_Ageing_Checkup2.xlsx
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup2.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record and auxvol...
# Handling sheets cycle, step and test...
# merging cycle and step...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# handling final merge...
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 12.199293 seconds
# Successfully processed: Cal_Ageing_Checkup2_Neware_2026-01-13_22-41-44
# Processing file: Cal_Ageing_Checkup3.xlsx
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup3.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record and auxvol...
# Handling sheets cycle, step and test...
# merging cycle and step...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# handling final merge...
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 11.120846 seconds
# Successfully processed: Cal_Ageing_Checkup3_Neware_2026-01-13_22-41-44
# Processing file: Cal_Ageing_Checkup4.xlsx
# converting file to pandas DataFrame...
# Reading sheets from ..\..\res\raw\Cal_Ageing_Checkup4.xlsx...
# hadling record auxvol auxtemp sheets...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record and auxvol...
# Handling sheets cycle, step and test...
# merging cycle and step...
# handling test sheet...
# merging cycle_step_test and test...
# checking if headers need to be reindexed...
# reindexing headers...
# merging record_auxvol and auxtemp...
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxvol.rename(columns={'Date': 'Date - auxVol', 'DataPoint': 'DataPoint - auxVol'}, inplace=True)
# C:\Users\Anton\Nextcloud\Organisation\Arbeit\Projekte\PyDPEET\pydpeet_dev\pydpeet\src\pydpeet\convert\zyklisierer\neware\reader.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auxtemp.rename(columns={'Date': 'Date - auxTemp', 'DataPoint': 'DataPoint - auxTemp'}, inplace=True)
# handling final merge...
# mapping columns...
#  WARNING: Missing column: 'EISFreq[Hz]'. Adding Collumn (with None values) named: 'EISFreq[Hz]'.
#  WARNING: Missing column: 'Zre[Ohm]'. Adding Collumn (with None values) named: 'Zre[Ohm]'.
#  WARNING: Missing column: 'Zim[Ohm]'. Adding Collumn (with None values) named: 'Zim[Ohm]'.
#  WARNING: Missing column: 'DC_Current[A]'. Adding Collumn (with None values) named: 'DC_Current[A]'.
# dropping additional data...
# adding metadata to Dataframe...
# Getting columns in correct order...
# Checking for duplicate extra columns...
# Selecting and ordering standard columns...
# Selecting extra columns...
# Combining standard and extra columns...
# Reordered DataFrame columns!
# Starting to fix data format...
# Using formatter for config: Config.Neware
# Data format fixed.
# convert_file executed in 10.310001 seconds
# Successfully processed: Cal_Ageing_Checkup4_Neware_2026-01-13_22-41-44
# convert_files_in_directory executed in 45.161514 seconds

# %% [markdown]
# After youre work is done you can export youre unifed and/or analyzed file.

# %%
eet.export() # todo: export files and list of files
